# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#identifyimg missing values in rows

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
#dropping off rows with missing rating since its just 1%
df = df.dropna(subset=['rating'])

# %%
#replacing missing values of budget and gross rows with their respective median values
df['budget'].fillna(df['budget'].median(), inplace=True)
df['gross'].fillna(df['gross'].median(), inplace=True)

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 0%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 0%
# gross - 0%
# company - 0%
# runtime - 0%

# %%
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Extract the year using a regular expression
df['corrected_year'] = df['released'].str.extract(r'(\d{4})')

# %%
print(df['corrected_year'].head())
# Out:
# 0    1980
# 1    1980
# 2    1980
# 3    1980
# 4    1980
# Name: corrected_year, dtype: object

# %%
df = df.dropna(subset=['corrected_year'])
df['corrected_year'] = df['corrected_year'].astype(int)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
#Drop any duplicates

df['company'].drop_duplicates()
# Out:
# 0                                            Warner Bros.
# 1                                       Columbia Pictures
# 2                                               Lucasfilm
# 3                                      Paramount Pictures
# 4                                          Orion Pictures
# 6                                      Universal Pictures
# 7                            Chartoff-Winkler Productions
# 8                                          Dovemead Films
# 9                                          United Artists
# 10                                    The Malpaso Company
# 11                                           C.A.T. Films
# 14                                      Filmways Pictures
# 15                                        Rastar Pictures
# 16                              Metro-Goldwyn-Mayer (MGM)
# 17                                              IPC Films
# 18                                  AVCO Embassy Pictures
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime', 'corrected_year'],
#       dtype='object')

# %%
#my guesses
#budget high correlation
#company high correlation
#genre
#score
#votes
#star

# %%
import matplotlib.pyplot as plt

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for film')
plt.ylabel('Gross Earnings')
plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Recast 'budget' and 'gross' columns to float64
df['budget'] = df['budget'].astype('float64')
df['gross'] = df['gross'].astype('float64')

# %%
import seaborn as sns

sns.regplot(x="budget", y="gross", data=df,
            scatter_kws={"color": "red"},
            line_kws={"color": "blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Print data types of each column to identify non-numeric columns
print(df.dtypes)
# Out:
# name               object
# rating             object
# genre              object
# year                int64
# released           object
# score             float64
# votes             float64
# director           object
# writer             object
# star               object
# country            object
# budget            float64
# gross             float64
# company            object
# runtime           float64
# corrected_year      int32
# dtype: object

# %%
# Drop the 'year' column from the DataFrame
df = df.drop(columns=['year'])

# %%
# Select only numeric columns from the DataFrame
numeric_df = df.select_dtypes(include=[np.number])

# Display the numeric columns
print(numeric_df.columns)
# Out:
# Index(['score', 'votes', 'budget', 'gross', 'runtime', 'corrected_year'], dtype='object')

# %%
# Calculate the correlation matrix for the numeric columns
correlation_matrix = numeric_df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                    score     votes    budget     gross   runtime  \
# score           1.000000  0.412012  0.062911  0.187791  0.400949
# votes           0.412012  1.000000  0.459207  0.632341  0.309664
# budget          0.062911  0.459207  1.000000  0.745667  0.273812
# gross           0.187791  0.632341  0.745667  1.000000  0.244442
# runtime         0.400949  0.309664  0.273812  0.244442  1.000000
# corrected_year  0.111232  0.222464  0.287523  0.255382  0.121238
#
#                 corrected_year
# score                 0.111232
# votes                 0.222464
# budget                0.287523
# gross                 0.255382
# runtime               0.121238
# corrected_year        1.000000

# %%
#correlation type is PEARSON

plt.figure(figsize=(10, 8))  # Adjust figure size
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)

plt.title("Correlation Matrix for Numeric Features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.show()

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime
# 0  1047       54  19000000.0   46998772.0     2319    146.0
# 1   327       55   4500000.0   58853106.0      731    104.0
# 2  1745       55  18000000.0  538375067.0     1540    124.0
# 3  2246       55   3500000.0   83453539.0     1812     88.0
# 4   410       55   6000000.0   39846344.0     1777     98.0

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  released  score      votes  director  writer  star  \
# 0  6519       6      6      1687    8.4   927000.0      2551    3966  1025
# 1  5510       6      1      1474    5.8    65000.0      2239    1615   316
# 2  5083       4      0      1753    8.7  1200000.0      1095    2538  1713
# 3   283       4      4      1474    7.7   221000.0      1282    1978  2203
# 4  1017       6      4      1525    7.3   108000.0      1039     513   398
#
#    country      budget        gross  company  runtime  corrected_year
# 0       54  19000000.0   46998772.0     2277    146.0            1980
# 1       55   4500000.0   58853106.0      713    104.0            1980
# 2       55  18000000.0  538375067.0     1509    124.0            1980
# 3       55   3500000.0   83453539.0     1773     88.0            1980
# 4       55   6000000.0   39846344.0     1740     98.0            1980

# %%
correlation_matrix = df_numerized.corr(method='pearson')

plt.figure(figsize=(10, 10))  # Adjust figure size
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)

plt.title("Correlation Matrix for Numeric Features")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.show()

# %%
df_numerized.copy().head()
# Out:
#    name  rating  genre  released  score      votes  director  writer  star  \
# 0  6519       6      6      1687    8.4   927000.0      2551    3966  1025
# 1  5510       6      1      1474    5.8    65000.0      2239    1615   316
# 2  5083       4      0      1753    8.7  1200000.0      1095    2538  1713
# 3   283       4      4      1474    7.7   221000.0      1282    1978  2203
# 4  1017       6      4      1525    7.3   108000.0      1039     513   398
#
#    country      budget        gross  company  runtime  corrected_year
# 0       54  19000000.0   46998772.0     2277    146.0            1980
# 1       55   4500000.0   58853106.0      713    104.0            1980
# 2       55  18000000.0  538375067.0     1509    124.0            1980
# 3       55   3500000.0   83453539.0     1773     88.0            1980
# 4       55   6000000.0   39846344.0     1740     98.0            1980

# %%
#Converts the square correlation matrix into a one-dimensional Series 

correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack() 
corr_pairs
# Out:
# name      name        1.000000
#           rating     -0.008069
#           genre       0.016355
#           year        0.011453
#           released   -0.011311
#           score       0.017097
#           votes       0.013088
#           director    0.009079
#           writer      0.009081
#           star        0.006472
#           country    -0.010737
#           budget      0.023970
#           gross       0.005533
#           company     0.009211
#           runtime     0.010392
# rating    name       -0.008069
#           rating      1.000000
#           genre       0.072423
#           year        0.008779
#           released    0.016613
#           score      -0.001314
#           votes       0.033225
#           director    0.019483
#           writer     -0.005921
#           star        0.013405
#           country     0.081244
#           budget     -0.176002
#           gross      -0.107339
#           company    -0.032943
#           runtime     0.062145
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget    genre      -0.356564
# genre     budget     -0.356564
#           gross      -0.235650
# gross     genre      -0.235650
# rating    budget     -0.176002
# budget    rating     -0.176002
# genre     votes      -0.145307
# votes     genre      -0.145307
# score     country    -0.133348
# country   score      -0.133348
# gross     rating     -0.107339
# rating    gross      -0.107339
# year      genre      -0.081261
# genre     year       -0.081261
# country   runtime    -0.078412
# runtime   country    -0.078412
# company   genre      -0.071067
# genre     company    -0.071067
# year      country    -0.070938
# country   year       -0.070938
# runtime   genre      -0.052711
# genre     runtime    -0.052711
# writer    budget     -0.039451
# budget    writer     -0.039451
# genre     country    -0.037615
# country   genre      -0.037615
# company   rating     -0.032943
# rating    company    -0.032943
# star      year       -0.027242
# year      star       -0.027242
# ...

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]
 
print(strong_pairs)
# Out:
# gross     votes       0.630757
# votes     gross       0.630757
# budget    gross       0.740395
# gross     budget      0.740395
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
#This analysis examines the relationships between various movie features, highlighting key correlations that may influence a movie's success. 

#Budget vs. Gross Earnings: A strong positive correlation (0.75) indicates that higher-budget films generally earn more at the box office.
#Votes vs. Gross Earnings: A moderately strong correlation (0.63) suggests that movies with more audience votes also tend to have higher earnings.
#Categorical Features:Perfect correlations were observed within features like `name`, `writer`, and `company`, as expected.

#Overall, the findings show that budget and audience engagement are significant predictors of a movie's financial success, 
# while runtime and score have weaker correlations with earnings.
